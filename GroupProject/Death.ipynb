# %%
import pandas as pd
import numpy as np
from functions import plot_deaths_by_state, plot_deaths_by_gender, plot_deaths_over_time

# Read the csv file
data = pd.read_csv('death_sex_ethnic_state.csv')

# BarChart of The Total Deaths by State 
plot_deaths_by_state(data, save_path='deaths_by_state_full_fixed.pdf')
# Out:
# Total deaths by state (Top 5):
# state
# Johor              1608812
# Kedah              1139020
# Kelantan            927376
# Melaka              438896
# Negeri Sembilan     566268
# Name: abs, dtype: int64

# %%
# BarChart of The Total Deaths by Gender 
plot_deaths_by_gender(data, save_path='deaths_by_gender.pdf')
# Out:
# Total deaths by gender:
# sex
# both      6564016
# female    2787430
# male      3776586
# Name: abs, dtype: int64

# %%
# LineChart of Trend of Deaths Over Time
plot_deaths_over_time(data, save_path='deaths_over_time.pdf')
# Out:
# Total deaths over time (First 5 dates):
# date
# 2000-01-01    402828
# 2001-01-01    418124
# 2002-01-01    441468
# 2003-01-01    450976
# 2004-01-01    452768
# Name: abs, dtype: int64
